# %%
# Lightweight notebook - keep your mount + paths as before
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import numpy as np
import requests
from bs4 import BeautifulSoup

from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    confusion_matrix, roc_curve, auc, precision_recall_curve
)
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split, GridSearchCV

# %%
import nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
detector = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...

# %%
# Paths (adjust if using Drive)
dataset_path = "/content/drive/MyDrive/FakeNewsProject/updated_news_dataset.csv"
vectorizer_path = "/content/drive/MyDrive/FakeNewsProject/tfidf_vectorizer.pkl"

# ---- Web scraping functions (minimal, safe) ----
def scrape_bbc(limit=20):
    try:
        url = "https://www.bbc.com/news"
        resp = requests.get(url, timeout=10)
        soup = BeautifulSoup(resp.text, "html.parser")
        items = soup.find_all("h3")
        texts = [it.get_text(strip=True) for it in items[:limit]]
        return pd.DataFrame({"text": texts, "label": 0})
    except Exception as e:
        print("BBC scrape error:", e)
        return pd.DataFrame(columns=["text", "label"])

def scrape_cnn(limit=20):
    try:
        url = "https://edition.cnn.com/world"
        resp = requests.get(url, timeout=10)
        soup = BeautifulSoup(resp.text, "html.parser")
        items = soup.find_all("span", class_="container__headline")
        texts = [it.get_text(strip=True) for it in items[:limit]]
        return pd.DataFrame({"text": texts, "label": 0})
    except Exception as e:
        print("CNN scrape error:", e)
        return pd.DataFrame(columns=["text", "label"])

def scrape_reuters(limit=20):
    try:
        url = "https://www.reuters.com/world/"
        resp = requests.get(url, timeout=10)
        soup = BeautifulSoup(resp.text, "html.parser")
        # Reuters site structure varies; find headlines broadly
        items = soup.find_all(["h2","h3"])
        texts = []
        for it in items:
            t = it.get_text(strip=True)
            if len(t) > 5:
                texts.append(t)
            if len(texts) >= limit:
                break
        return pd.DataFrame({"text": texts, "label": 0})
    except Exception as e:
        print("Reuters scrape error:", e)
        return pd.DataFrame(columns=["text", "label"])

# %%
def get_all_real_news(limit_each=10):
    # small number each to avoid heavy scraping
    a = scrape_bbc(limit=limit_each)
    b = scrape_cnn(limit=limit_each)
    c = scrape_reuters(limit=limit_each)
    return pd.concat([a,b,c], ignore_index=True)

# ---- Load dataset and append scraped real news ----
df = pd.read_csv(dataset_path)

# Append scraped real news headlines (only a few) to enrich real news examples
scraped = get_all_real_news(limit_each=10)   # total up to ~30 new real samples
if not scraped.empty:
    df = pd.concat([df, scraped], ignore_index=True)
    df = df.sample(frac=1, random_state=42).reset_index(drop=True)  # reshuffle

# Load TF-IDF vectorizer
vectorizer = joblib.load(vectorizer_path)

# Raw texts and labels
X_raw = df["text"]
y = df["label"]

# Split raw strings first, then transform — prevents leakage and keeps raw texts for sentiment
X_train_raw, X_test_raw, y_train, y_test = train_test_split(
    X_raw, y, test_size=0.2, random_state=42, stratify=y
)

# Transform after split
X_train = vectorizer.transform(X_train_raw)
X_test = vectorizer.transform(X_test_raw)

# %%
def optimize_logistic_regression(X_train_vec, y_train):
    param_grid = {'C': [0.01, 0.1, 1, 10], 'penalty': ['l2'], 'solver': ['lbfgs', 'liblinear']}
    grid = GridSearchCV(LogisticRegression(max_iter=1000), param_grid, cv=5, n_jobs=-1, verbose=1)
    grid.fit(X_train_vec, y_train)
    return grid.best_estimator_

# %%
def evaluate_model(name, model, X_train, X_test, y_train, y_test, X_test_raw=None):
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    y_prob = model.predict_proba(X_test)[:, 1] if hasattr(model, "predict_proba") else None

    acc = accuracy_score(y_test, y_pred)
    prec = precision_score(y_test, y_pred, zero_division=0)
    rec = recall_score(y_test, y_pred, zero_division=0)
    f1 = f1_score(y_test, y_pred, zero_division=0)

    print(f"\n=== {name} ===")
    print(f"Accuracy: {acc:.4f} | Precision: {prec:.4f} | Recall: {rec:.4f} | F1: {f1:.4f}")

    cm = confusion_matrix(y_test, y_pred)
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=["Real", "Fake"], yticklabels=["Real", "Fake"])
    plt.title(f"{name} - Confusion Matrix")
    plt.show()

    if y_prob is not None:
        fpr, tpr, _ = roc_curve(y_test, y_prob)
        roc_auc = auc(fpr, tpr)
        plt.plot(fpr, tpr, label=f'{name} (AUC={roc_auc:.2f})'); plt.plot([0,1],[0,1],'k--')
        plt.xlabel("False Positive Rate"); plt.ylabel("True Positive Rate"); plt.title(f"ROC Curve - {name}"); plt.legend(); plt.show()
        precision_vals, recall_vals, _ = precision_recall_curve(y_test, y_prob)
        plt.plot(recall_vals, precision_vals, label=name); plt.xlabel("Recall"); plt.ylabel("Precision"); plt.title(f"Precision-Recall Curve - {name}"); plt.legend(); plt.show()

    # Sentiment analysis on raw test texts
    avg_sent = np.nan; avg_sent_pred_fake = np.nan; avg_sent_pred_real = np.nan
    if X_test_raw is not None:
        sent_compounds = np.array([detector.polarity_scores(str(t))['compound'] for t in X_test_raw])
        avg_sent = sent_compounds.mean()
        mask_pred_fake = (y_pred == 1); mask_pred_real = (y_pred == 0)
        if mask_pred_fake.any(): avg_sent_pred_fake = sent_compounds[mask_pred_fake].mean()
        if mask_pred_real.any(): avg_sent_pred_real = sent_compounds[mask_pred_real].mean()
        print(f"Average sentiment (compound) on TEST set: {avg_sent:.4f}")
        print(f"Average sentiment for samples PREDICTED as Fake: {avg_sent_pred_fake}")
        print(f"Average sentiment for samples PREDICTED as Real: {avg_sent_pred_real}")

    return {"Model": name, "Accuracy": acc, "Precision": prec, "Recall": rec, "F1": f1,
            "Avg_Sentiment": avg_sent, "Avg_Sent_Pred_Fake": avg_sent_pred_fake, "Avg_Sent_Pred_Real": avg_sent_pred_real}

# %%
# Define lightweight models
light_models = {
    "Naive Bayes": MultinomialNB(),
    "Logistic Regression": optimize_logistic_regression(X_train, y_train),
    "KNN": KNeighborsClassifier(n_neighbors=5)
}

# Run evaluations and save
light_results = []
for name, model in light_models.items():
    res = evaluate_model(name, model, X_train, X_test, y_train, y_test, X_test_raw=X_test_raw)
    light_results.append(res)

df_light_results = pd.DataFrame(light_results)
print("\n📊 Lightweight Models Results:\n", df_light_results)
df_light_results.to_csv("/content/light_model_results.csv", index=False)
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
#
# === Naive Bayes ===
# Accuracy: 0.9353 | Precision: 0.9358 | Recall: 0.9408 | F1: 0.9383
# Average sentiment (compound) on TEST set: -0.0212
# Average sentiment for samples PREDICTED as Fake: -0.09543160347384029
# Average sentiment for samples PREDICTED as Real: 0.06118220239492839
#
# === Logistic Regression ===
# Accuracy: 0.9930 | Precision: 0.9930 | Recall: 0.9936 | F1: 0.9933
# Average sentiment (compound) on TEST set: -0.0212
# Average sentiment for samples PREDICTED as Fake: -0.09430248989146627
# Average sentiment for samples PREDICTED as Real: 0.059138005138986205
#
# === KNN ===
# Accuracy: 0.6375 | Precision: 0.5921 | Recall: 0.9864 | F1: 0.7400
# Average sentiment (compound) on TEST set: -0.0212
# Average sentiment for samples PREDICTED as Fake: -0.031463862968170775
# Average sentiment for samples PREDICTED as Real: 0.04856024200518583
#
# 📊 Lightweight Models Results:
#                   Model  Accuracy  Precision    Recall        F1  \
# 0          Naive Bayes  0.935301   0.935819  0.940801  0.938303
# 1  Logistic Regression  0.992984   0.992977  0.993612  0.993294
# 2                  KNN  0.637528   0.592100  0.986371  0.739995
#
#    Avg_Sentiment  Avg_Sent_Pred_Fake  Avg_Sent_Pred_Real
# 0      -0.021153           -0.095432            0.061182
# 1      -0.021153           -0.094302            0.059138
# 2      -0.021153           -0.031464            0.048560
